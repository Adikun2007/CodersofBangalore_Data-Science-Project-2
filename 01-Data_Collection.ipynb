# %% [markdown]
# # Welcome Sam Altman to Bangalore
# #### You ask Sam Altman for 2.2 billion USD in funding, and he makes fun of you in public
#
# #### He asks you where you live, and finally, after talking to you, gives you a challenging task
#
# #### Collect raw Instagram data of all OpenAI followers
#
# ### Answer these questions:
#
# - Who has the maximum posts
# - who has the maximum followers
# - Who follows the maximum people
# - How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?
# ### You have 24 hours!
#
# #### You then ask for data - he laughs!

# %% [markdown]
# # Data Collection in Indiranagar
# #### You hire Vijyalaxmi Iyer and Sam Chandra to help with the project. Vijyalaxmi lives all the way in Hebbal, and Sam stays in HSR Layout, so meeting at either place would be a long trip for someone. To keep things fair, you decide to set up a meeting at Rameshwaram Café in Indiranagar, a perfect midway point.
#
# #### Three of you sit down and lay out the entire project plan. You break the work into two major parts:
#
# #### Laxmi and Sam will be in charge of collecting the Instagram follower data.
# #### You will build the Python Script that will process everything.
# #### By the end of the meeting, everyone is aligned: Laxmi and Sam will focus on accurate data collection, and you’ll focus on making sure the code can handle real-world data seamlessly. The team is ready, the plan is set, and the project officially kicks off.

# %%
with open("initialdata.txt","r",encoding = 'utf-8') as f:
    data = f.read()

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(c)>3]
print(chunks[0])
# Out:
# intaglobal
# 1,946 posts
# 6,851 followers
# 262 following
# INTA
# Nonprofit organization
# The association of ™ professionals.
# inta.campsite.bio

# %%
def parse_chunk(chunk):
    
    chunk = chunk.strip()
    separated_chunk = chunk.split("\n")
    user_name = separated_chunk[0]
    no_of_posts = separated_chunk[1]
    no_of_followers = separated_chunk[2]
    no_of_following = separated_chunk[3]
    real_name = separated_chunk[4]
    if (len(separated_chunk)>5):
        type_of_page = separated_chunk[5]
        user_bio = "\n".join(separated_chunk[6:])
    else:
        type_of_page = "Unknown"
        user_bio = ""
        
    return {"user_name": user_name, "no_of_posts": no_of_posts, "no_of_followers": no_of_followers, 
            "no_of_following": no_of_following, "real_name": real_name, "type_of_page": type_of_page, 
            "user_bio": user_bio} 

# print(parse_chunk(chunks[0]))

# %%
all_chunks = []
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'user_name': 'intaglobal', 'no_of_posts': '1,946 posts', 'no_of_followers': '6,851 followers', 'no_of_following': '262 following', 'real_name': 'INTA', 'type_of_page': 'Nonprofit organization', 'user_bio': 'The association of ™ professionals.\ninta.campsite.bio'}, {'user_name': '_anujsinghal', 'no_of_posts': '1,785 posts', 'no_of_followers': '681K followers', 'no_of_following': '248 following', 'real_name': 'Anuj Singhal', 'type_of_page': 'Digital creator', 'user_bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}, {'user_name': 'code_flare', 'no_of_posts': '165 posts', 'no_of_followers': '216 followers', 'no_of_following': '10 following', 'real_name': 'The Journey Notebook | Travel | Food Blogger', 'type_of_page': 'Blogger', 'user_bio': '📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a'}, {'user_name': 'bangalore_tech_bro', 'no_of_posts': '402 posts', 'no_of_followers': '12.5K followers', 'no_of_following': '890 following', 'real_name': 'Rahul | HSR Hustler', 'type_of_page': 'Entrepreneur', 'user_bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}, {'user_name': 'silkboard_survivor', 'no_of_posts': '55 posts', 'no_of_followers': '1,200 followers', 'no_of_following': '50 following', 'real_name': 'Priya D.', 'type_of_page': 'Public Figure', 'user_bio': '🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants'}, {'user_name': 'startuphub_blr', 'no_of_posts': '2,300 posts', 'no_of_followers': '45K followers', 'no_of_following': '120 following', 'real_name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'user_bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}, {'user_name': 'foodie_in_kora', 'no_of_posts': '890 posts', 'no_of_followers': '5,600 followers', 'no_of_following': '400 following', 'real_name': 'Sneha | Bangalore Eats', 'type_of_page': 'Food & Drink', 'user_bio': "Aagrah to Truffles 🍔\nExploring Koramangala's cafe culture ☕\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123"}, {'user_name': 'venture_vikram', 'no_of_posts': '120 posts', 'no_of_followers': '30K followers', 'no_of_following': '500 following', 'real_name': 'Vikram | Angel Investor', 'type_of_page': 'Investor', 'user_bio': '💸 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n📍 Indiranagar\nvikram.vc/pitch-deck'}, {'user_name': 'python_meetup_blr', 'no_of_posts': '60 posts', 'no_of_followers': '3,400 followers', 'no_of_following': '10 following', 'real_name': 'PyBangalore Community', 'type_of_page': 'Community', 'user_bio': '🐍 Weekly meetups for Pythonistas\n📍 Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore'}, {'user_name': 'indiranagar_gossip', 'no_of_posts': '300 posts', 'no_of_followers': '8,900 followers', 'no_of_following': '20 following', 'real_name': 'Indiranagar Spy', 'type_of_page': 'Personal Blog', 'user_bio': 'Not just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy'}, {'user_name': 'ig_arbin07', 'no_of_posts': '50 posts', 'no_of_followers': '33 followers', 'no_of_following': '30 following', 'real_name': 'aarbinnn', 'type_of_page': 'Gamer', 'user_bio': '@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️'}, {'user_name': '7iiuliiu', 'no_of_posts': '1 post', 'no_of_followers': '44 followers', 'no_of_following': '166 following', 'real_name': '︎𝐄︎ ♡︎.', 'type_of_page': 'Unknown', 'us ...

# %%
import json
s = json.dumps(all_chunks, indent=4)
print(s)
# Out:
# [
#     {
#         "user_name": "intaglobal",
#         "no_of_posts": "1,946 posts",
#         "no_of_followers": "6,851 followers",
#         "no_of_following": "262 following",
#         "real_name": "INTA",
#         "type_of_page": "Nonprofit organization",
#         "user_bio": "The association of \u2122 professionals.\ninta.campsite.bio"
#     },
#     {
#         "user_name": "_anujsinghal",
#         "no_of_posts": "1,785 posts",
#         "no_of_followers": "681K followers",
#         "no_of_following": "248 following",
#         "real_name": "Anuj Singhal",
#         "type_of_page": "Digital creator",
#         "user_bio": "Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet\u2019s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul"
#     },
#     {
#         "user_name": "code_flare",
#         "no_of_posts": "165 posts",
#         "no_of_followers": "216 followers",
#         "no_of_following": "10 following",
#         "real_name": "The Journey Notebook | Travel | Food Blogger",
#         "type_of_page": "Blogger",
#         "user_bio": "\ud83d\udccd Exploring places & phases of life \ud83c\udf0d\n.\n\ud83c\udf75 From chai breaks to flight takes \u2708\ufe0f\n.\n\ud83d\udcab Travel | Food | Daily life \ud83c\udf38\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a"
#     },
#     {
#         "user_name": "bangalore_tech_bro",
#         "no_of_posts": "402 posts",
#         "no_of_followers": "12.5K followers",
#         "no_of_following": "890 following",
#         "real_name": "Rahul | HSR Hustler",
#         "type_of_page": "Entrepreneur",
#         "user_bio": "\ud83d\ude80 Building the next Unicorn in Fintech\n\u2615 3rd Wave Coffee addict\n\ud83d\udcbb Python | React | AI\n\ud83d\udccd HSR Layout, BLR\nlinktr.ee/rahulbuilds"
#     },
#     {
#         "user_name": "silkboard_survivor",
#         "no_of_posts": "55 posts",
#         "no_of_followers": "1,200 followers",
#         "no_of_following": "50 following",
#         "real_name": "Priya D.",
#         "type_of_page": "Public Figure",
#         "user_bio": "\ud83d\udea6 Stuck in traffic since 2019\n\ud83c\udf27\ufe0f Loving the Bangalore weather, hating the cabs\n\ud83d\udc0d Data Scientist by day, meme maker by night\n\ud83d\udccd ORR\nbit.ly/my-traffic-rants"
#     },
#     {
#         "user_name": "startuphub_blr",
#         "no_of_posts": "2,300 posts",
#         "no_of_followers": "45K followers",
#         "no_of_following": "120 following",
#         "real_name": "Startup Hub Bangalore",
#         "type_of_page": "Media",
#         "user_bio": "\ud83e\udd84 News from the Silicon Valley of India\n\ud83d\udce2 Funding alerts, Hiring trends, and Drama\n\ud83d\udce9 DM for features\nstartuphub.blr/newsletter"
#     },
#     {
#         "user_name": "foodie_in_kora",
#         "no_of_posts": "890 posts",
#         "no_of_followers": "5,600 followers",
#         "no_of_following": "400 following",
#         "real_name": "Sneha | Bangalore Eats",
#         "type_of_page": "Food & Drink",
#         "user_bio": "Aagrah to Truffles \ud83c\udf54\nExploring Koramangala's cafe culture \u2615\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123"
#     },
#     {
#         "user_name": "venture_vikram",
#         "no_of_posts": "120 posts",
#         "no_of_followers": "30K followers",
#         "no_of_following": "500 following",
#         "real_name": "Vikram | Angel Investor",
#         "type_of_page": "Investor",
#         "user_bio": "\ud83d\udcb8 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n\ud83d\udccd Indiranagar\nvikram.vc/pitch-deck"
#     },
#     {
#         "user_name": "python_meetup_blr",
#         "no_of_posts": "60 posts",
#         "no_of_followers": "3,400 followers",
#         "no_of_following": "10 following",
#         "real_name": "PyBangalore Community",
#         "type_of_page": "Community",
#         "user_bio": "\ud83d\udc0d Weekly meetups for Pythonistas\n\ud83d\udccd Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore"
#     },
#     {
#         "user_name": "indiranagar_gossip",
#         "no_of_posts": "300 posts",
#         "no_of_followers": "8,900 followers",
#         "no_of_following": "20 following",
#         "real_name": "Indiranagar Spy",
#         "type_of_page": "Personal Blog",
#         "user_bio": "Not just about 100ft Road \ud83e\udd2b\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy"
#     },
#     {
#         "user_name": "ig_arbin07",
#         "no_of_posts": "50 posts",
#         "no_of_followers": "33 followers",
#         "no_of_following": "30 following",
#         "real_name": "aarbinnn",
#         "type_of_page": "Gamer",
#         "user_bio": "@dumb.arbin\n\ud83c\udfae: Banana\u300ejuice (IGL\ud83e\udd77)\nGamer never die, they just respawn\ud83d\ude42\u200d\u2194\ufe0f"
#     },
#     {
#         "user_name": "7iiuliiu",
#         "no_of_posts": "1 post",
#         "no_of_followers": "44 followers",
#         "no_of_following": "166 following",
#         "real_name": "\ufe0e\ud835\udc04\ufe0e \u2661\ufe0e.",
#         "type_of_page": "Unknown",
#         "user_bio": ""
#     },
#     {
#         "user_name": "katiasales2220",
#         "no_of_posts": "107 posts",
#         "no_of_followers": "219 followers",
#         "no_of_following": "1,401 following",
#         "real_name": "Katia Sales",
#         "type_of_page": "Alfabetiza\u00e7\u00e3o e Refor\u00e7o Escolar",
#         "user_bio": "Ensino Fundamental I e II\nPrepara\u00e7\u00e3o para Escola Militar\nPortugu\u00eas e Matem\u00e1tica\nCursando Psicopedagogia Est\u00e1cio"
#     }
# ]
