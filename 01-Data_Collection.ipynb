# %% [markdown]
# # Welcome Sam Altman to Bangalore
# #### You ask Sam Altman for 2.2 billion USD in funding, and he makes fun of you in public
#
# #### He asks you where you live, and finally, after talking to you, gives you a challenging task
#
# #### Collect raw Instagram data of all OpenAI followers
#
# ### Answer these questions:
#
# - Who has the maximum posts
# - who has the maximum followers
# - Who follows the maximum people
# - How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?
# ### You have 24 hours!
#
# #### You then ask for data - he laughs!

# %% [markdown]
# # Data Collection in Indiranagar
# #### You hire Vijyalaxmi Iyer and Sam Chandra to help with the project. Vijyalaxmi lives all the way in Hebbal, and Sam stays in HSR Layout, so meeting at either place would be a long trip for someone. To keep things fair, you decide to set up a meeting at Rameshwaram Café in Indiranagar, a perfect midway point.
#
# #### Three of you sit down and lay out the entire project plan. You break the work into two major parts:
#
# #### Laxmi and Sam will be in charge of collecting the Instagram follower data.
# #### You will build the Python Script that will process everything.
# #### By the end of the meeting, everyone is aligned: Laxmi and Sam will focus on accurate data collection, and you’ll focus on making sure the code can handle real-world data seamlessly. The team is ready, the plan is set, and the project officially kicks off.

# %%
with open("finaldata.txt","r",encoding = 'utf-8') as f:
    data = f.read()

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(c)>3]
print(chunks[0])
# Out:
# techie_koramangala
# 420 posts
# 9,800 followers
# 310 following
# Arjun M.
# Software Engineer
# 💻 Full-stack @ SaaS startup
# ☕ Working from cafes in Koramangala
# github.com/arjunmakes

# %%
def parse_chunk(chunk):
    
    chunk = chunk.strip()
    separated_chunk = chunk.split("\n")
    user_name = separated_chunk[0]
    
    no_of_posts = int(separated_chunk[1].split(" post")[0].replace(",", ""))
    
    no_of_followers = float(separated_chunk[2].split(" follower")[0].replace(",", "").replace("K", "").replace("M", ""))
    if ("K" in separated_chunk[2]):
        no_of_followers = int(no_of_followers*1000)
    elif ("M" in separated_chunk[2]):
        no_of_followers = int(no_of_followers*1000000)
    else:
        no_of_followers=int(no_of_followers)
        
    no_of_following = float(separated_chunk[3].split(" following")[0].replace(",", "").replace("K", "").replace("M", ""))
    if ("K" in separated_chunk[3]):
        no_of_following = int(no_of_following*1000)
    elif ("M" in separated_chunk[3]):
        no_of_following = int(no_of_following*1000000)
    else:
        no_of_following=int(no_of_following)
    
    real_name = separated_chunk[4]
    if (len(separated_chunk)>5):
        type_of_page = separated_chunk[5]
        user_bio = "\n".join(separated_chunk[6:])
    else:
        type_of_page = "Unknown"
        user_bio = ""
        
    return {"user_name": user_name, "no_of_posts": no_of_posts, "no_of_followers": no_of_followers, 
            "no_of_following": no_of_following, "real_name": real_name, "type_of_page": type_of_page, 
            "user_bio": user_bio} 

# print(parse_chunk(chunks[0]))

# %%
all_chunks = []
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'user_name': 'techie_koramangala', 'no_of_posts': 420, 'no_of_followers': 9800, 'no_of_following': 310, 'real_name': 'Arjun M.', 'type_of_page': 'Software Engineer', 'user_bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}, {'user_name': 'blrcoder_girl', 'no_of_posts': 150, 'no_of_followers': 6300, 'no_of_following': 120, 'real_name': 'Riya Codes', 'type_of_page': 'Tech Creator', 'user_bio': '👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'}, {'user_name': 'hsr_startup_stories', 'no_of_posts': 980, 'no_of_followers': 22400, 'no_of_following': 95, 'real_name': 'Startup Stories HSR', 'type_of_page': 'Media', 'user_bio': '🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com'}, {'user_name': 'cloud_dev_blr', 'no_of_posts': 210, 'no_of_followers': 4500, 'no_of_following': 60, 'real_name': 'Naveen DevOps', 'type_of_page': 'Engineer', 'user_bio': '☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud'}, {'user_name': 'koramangala_coffee_lover', 'no_of_posts': 300, 'no_of_followers': 7900, 'no_of_following': 180, 'real_name': 'Sana B.', 'type_of_page': 'Cafe Explorer', 'user_bio': '☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter'}, {'user_name': 'ai_bangalore_news', 'no_of_posts': 1340, 'no_of_followers': 38000, 'no_of_following': 200, 'real_name': 'AI Bangalore', 'type_of_page': 'Media', 'user_bio': '🤖 Daily AI news from India\n📢 Startup & research updates\naibanglore.ai/news'}, {'user_name': 'techfounder_india', 'no_of_posts': 210, 'no_of_followers': 19000, 'no_of_following': 450, 'real_name': 'Dev Patel', 'type_of_page': 'Founder', 'user_bio': '⚡ Building SaaS in Fintech\n📍 Indiranagar\ndevpatel.io'}, {'user_name': 'coder_on_orr', 'no_of_posts': 65, 'no_of_followers': 1900, 'no_of_following': 70, 'real_name': 'Sriram', 'type_of_page': 'Backend Developer', 'user_bio': '🐍 Python | FastAPI enthusiast\n🌧️ Surviving ORR traffic\ngithub.com/sriramworks'}, {'user_name': 'blrdatascience_daily', 'no_of_posts': 540, 'no_of_followers': 15100, 'no_of_following': 150, 'real_name': 'Bangalore DS Daily', 'type_of_page': 'Media', 'user_bio': '📊 Data + AI + ML\n👩\u200d🏫 Tutorials | Job alerts\nblrdatascience.in'}, {'user_name': 'frontend_with_megha', 'no_of_posts': 175, 'no_of_followers': 8200, 'no_of_following': 95, 'real_name': 'Megha Gupta', 'type_of_page': 'Frontend Dev', 'user_bio': '🎨 React | Next.js | UI Tips\n🌸 Bengaluru\nmeghacodes.dev'}, {'user_name': 'cubbonpark_runner', 'no_of_posts': 95, 'no_of_followers': 1500, 'no_of_following': 40, 'real_name': 'Aman', 'type_of_page': 'Lifestyle', 'user_bio': '🏃 Running after coding\n📍 Cubbon Park\nstrava.com/amanrunning'}, {'user_name': 'indiranagar_food_maps', 'no_of_posts': 600, 'no_of_followers': 12300, 'no_of_following': 155, 'real_name': 'Food Maps BLR', 'type_of_page': 'Food & Drink', 'user_bio': '🍜 Maps of best places around Indiranagar\n📍 Bangalore\nfoodmapsblr.com'}, {'user_name': 'python_blr_jobs', 'no_of_posts': 1200, 'no_of_followers': 21000, 'no_of_following': 18, 'real_name': 'Python Jobs BLR', 'type_of_page': 'Community', 'user_bio': '💼 Python/ML/AI jobs daily\n📍 Bengaluru\npythonblr.jobs'}, {'user_name': 'sarjapur_coder', 'no_of_posts': 143, 'no_of_followers': 3200, 'no_of_following': 52, 'real_name': 'Roshan', 'type_of_page': 'Full-stack Dev', 'user_bio': '🧑\u200d💻 MERN | DevTools\nCurrently debugging from Sarjapur\nroshancodes.dev'}, {'user_name': 'open_source_blr', 'no_of_posts': 300, 'no_of_followers': 9100, 'no_of_following': 78, 'real_name': 'BLR Open Source', 'type_of_page': 'Community', 'user_bio': '🌐 Meetups | Talks | OSS\ngithub.com/blropensource'}, {'user_name': 'techwalk_blr', 'no_of_posts': 430, 'no_of_followers': 11000, 'no_of_following': 320, 'real_name': 'Tech Walk Bangalore', 'type_of_page': 'Media', 'user_bio': '🚶 Exploring tech parks & cafes\n📍 Ecoworld | Manyata | Bagmane\ntechwalkblr.com'}, {'use ...

# %%
import json
s = json.dumps(all_chunks, indent=4)

# %% [markdown]
# # Who has the maximum posts
# ### finding out who has maximum posts

# %%
max = 0
for chunk in all_chunks:
    if (max<chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_posts = chunk
print(chunk_with_max_posts)
# Out:
# {'user_name': 'startuphub_blr', 'no_of_posts': 2300, 'no_of_followers': 45000, 'no_of_following': 120, 'real_name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'user_bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %% [markdown]
# # who has the maximum followers
#
# #### finding out who has maximum no of followers

# %%
max_follower = 0
for chunk in all_chunks:
    if (max_follower < chunk['no_of_followers']):
        max_follower = chunk['no_of_followers']
        chunk_with_max_follower = chunk
print(chunk_with_max_follower)
# Out:
# {'user_name': '_anujsinghal', 'no_of_posts': 1785, 'no_of_followers': 681000, 'no_of_following': 248, 'real_name': 'Anuj Singhal', 'type_of_page': 'Digital creator', 'user_bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %% [markdown]
# # Who follows the maximum people
# #### finding out who follows maximum no of people

# %%
max_following = 0
for chunk in all_chunks:
    if (max_following < chunk['no_of_following']):
        max_following = chunk['no_of_following']
        chunk_with_max_following = chunk
print(chunk_with_max_following)
# Out:
# {'user_name': 'bangalore_tech_bro', 'no_of_posts': 402, 'no_of_followers': 12500, 'no_of_following': 890, 'real_name': 'Rahul | HSR Hustler', 'type_of_page': 'Entrepreneur', 'user_bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}

# %% [markdown]
# # How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?
#
# #### finding out no of categories

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print({"No of people we have:", len(categories)})
# Out:
# {34, 'No of people we have:'}
